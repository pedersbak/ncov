# %%
#! pip install BeautifulSoup4 requests
import tabula
import os
import pandas as pd
import numpy as np

# %%
import requests

import os

dir_name = "../data"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".pdf"):
        os.remove(os.path.join(dir_name, item))


from bs4 import BeautifulSoup
#import urllib2
import re
linkList=[]
html_page = requests.get('https://www.who.int/emergencies/diseases/novel-coronavirus-2019/situation-reports').content
soup = BeautifulSoup(html_page)
#print(html_page)
#, attrs={'href': re.compile("^http://")}
for link in soup.findAll('a'):
    l=str(link)
    m = re.search('/docs/(.+?).pdf', l)
    if m:
        foundLink = m.group(1)    #if 'sitrep' in link.get('href'):
        #print(found)
        linkList.append('https://who.int/docs/'+foundLink+'.pdf')

for link in linkList :
    #url = 'https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200121-sitrep-'+str(i)+'-2019-ncov.pdf'
    #print('Downloading '+url)
    myfile = requests.get(link)
    #print()
    targetFileName=os.path.basename(link)
    print('Writing '+targetFileName)
    with open('../data/'+targetFileName, 'wb') as f:
        f.write(myfile.content)
# Out:
# Writing 20200202-sitrep-13-ncov-v3.pdf
# Writing 20200201-sitrep-12-ncov.pdf
# Writing 20200131-sitrep-11-ncov.pdf
# Writing 20200130-sitrep-10-ncov.pdf
# Writing 20200129-sitrep-9-ncov-v2.pdf
# Writing 20200128-sitrep-8-ncov-cleared.pdf
# Writing 20200127-sitrep-7-2019--ncov.pdf
# Writing 20200126-sitrep-6-2019--ncov.pdf
# Writing 20200125-sitrep-5-2019-ncov.pdf
# Writing 20200124-sitrep-4-2019-ncov.pdf
# Writing 20200123-sitrep-3-2019-ncov.pdf
# Writing 20200122-sitrep-2-2019-ncov.pdf
# Writing 20200121-sitrep-1-2019-ncov.pdf

# %%
pages=[]
for filename in os.listdir('../data/'):
    if filename.endswith('.pdf'):
        dt=(filename[:8])
        dflist = tabula.read_pdf('../data/'+filename, pages='all', silent=True)
        for df in dflist:
            df['Date']=pd.Series([pd.to_datetime(dt) for i in range(0, len(df))])
            df['Filename']=pd.Series([filename for i in range(0, len(df))])
        pages.append(dflist)

# %%
def findNumber(df):
    t=False
    for i, row in df.iterrows():
        #print('***')
        r=False
        for y in range(0, len(row)):
            #print(i,y)
            #print(str(row[y]).lower().strip())
            #Is this the right table ?
            if 'japan' in str(row[y]).lower().strip(): 
                t=True
                #print(row)
                # Is this the right row ?
            if 'total' in str(row[y]).lower() or 'confirmed' in str(row[y]).lower():
                r=True
            if r==True & t==True:
                if str(row[y]).split('.')[0].replace(',','').isdigit():
                    return row['Date'].date(), int(str(row[y]).split('.')[0].replace(',','')), row['Filename']

# %%
dates, confirmedCases, file=[],[],[]
for page in pages:
    if len(page)>0:
        for i, df in enumerate(page):
            try:
                dt, number, filename = findNumber(df)
                dates.append(dt)
                confirmedCases.append(number)
                file.append(filename)
                print(dt,number, filename)
            except Exception as e:
                pass
dataTable=pd.DataFrame({'Date':dates, 'confirmedcases':confirmedCases, 'File':file})
dataTable=dataTable.sort_values('Date')
dataTable['C'] = np.arange(len(dataTable))+1
dataTable=dataTable.sort_values('C')

print("Writing csv-file")
dataTable.to_csv('../data/dataTable.csv')
# Out:
# 2020-02-02 14557 20200202-sitrep-13-ncov-v3.pdf
# 2020-01-28 4593 20200128-sitrep-8-ncov-cleared.pdf
# 2020-01-27 2798 20200127-sitrep-7-2019--ncov.pdf
# 2020-01-31 9826 20200131-sitrep-11-ncov.pdf
# 2020-01-21 282 20200121-sitrep-1-2019-ncov.pdf
# 2020-01-22 314 20200122-sitrep-2-2019-ncov.pdf
# 2020-01-25 1320 20200125-sitrep-5-2019-ncov.pdf
# 2020-02-01 11953 20200201-sitrep-12-ncov.pdf
# 2020-01-26 2014 20200126-sitrep-6-2019--ncov.pdf
# 2020-01-30 7818 20200130-sitrep-10-ncov.pdf
# 2020-01-23 581 20200123-sitrep-3-2019-ncov.pdf
# 2020-01-29 6065 20200129-sitrep-9-ncov-v2.pdf
# 2020-01-24 846 20200124-sitrep-4-2019-ncov.pdf
# Writing csv-file

# %%
dataTable=pd.DataFrame({'Date':dates, 'Confirmed cases':confirmedCases, 'File':file})
dataTable.sort_values('Date')
# Out:
#     Confirmed cases        Date                                File
# 4               282  2020-01-21     20200121-sitrep-1-2019-ncov.pdf
# 5               314  2020-01-22     20200122-sitrep-2-2019-ncov.pdf
# 10              581  2020-01-23     20200123-sitrep-3-2019-ncov.pdf
# 12              846  2020-01-24     20200124-sitrep-4-2019-ncov.pdf
# 6              1320  2020-01-25     20200125-sitrep-5-2019-ncov.pdf
# 8              2014  2020-01-26    20200126-sitrep-6-2019--ncov.pdf
# 2              2798  2020-01-27    20200127-sitrep-7-2019--ncov.pdf
# 1              4593  2020-01-28  20200128-sitrep-8-ncov-cleared.pdf
# 11             6065  2020-01-29       20200129-sitrep-9-ncov-v2.pdf
# 9              7818  2020-01-30         20200130-sitrep-10-ncov.pdf
# 3              9826  2020-01-31         20200131-sitrep-11-ncov.pdf
# 7             11953  2020-02-01         20200201-sitrep-12-ncov.pdf
# 0             14557  2020-02-02      20200202-sitrep-13-ncov-v3.pdf

# %%
% matplotlib inline
dataTable.set_index('Date')['Confirmed cases'].plot(figsize=(10,10))

# %%
data=pd.read_csv('../data/dataTable.csv', parse_dates=['Date'])[['Date','Confirmed cases']]
data['dateStr']=data['Date'].dt.date.astype(str)
data.set_index('Date')[['dateStr','Confirmed cases']]
data['C'] = np.arange(len(data))+1

# %%
#! pip install BeautifulSoup4 requests
import tabula
import pandas as pd
from bs4 import BeautifulSoup
import re
import requests
import os
import numpy as np


def delete():
    dir_name = "../data"
    test = os.listdir(dir_name)
    for item in test:
        if item.endswith(".pdf"):
            os.remove(os.path.join(dir_name, item))


def download():
    linkList = []
    html_page = requests.get(
        'https://www.who.int/emergencies/diseases/novel-coronavirus-2019/situation-reports').content
    soup = BeautifulSoup(html_page, features="lxml")
    for link in soup.findAll('a'):
        l = str(link)
        m = re.search('/docs/(.+?).pdf', l)
        if m:
            foundLink = m.group(1)  # if 'sitrep' in link.get('href'):
            # print(found)
            linkList.append('https://who.int/docs/' + foundLink + '.pdf')

    for link in linkList:
        # url = 'https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200121-sitrep-'+str(i)+'-2019-ncov.pdf'
        #print('Downloading '+url)
        myfile = requests.get(link)
        #print()
        targetFileName = os.path.basename(link)
        print('Writing ' + targetFileName)
        with open('../data/' + targetFileName, 'wb') as f:
            f.write(myfile.content)


def findNumber(df):
    t = False
    for i, row in df.iterrows():
        r = False
        for y in range(0, len(row)):
            #Is this the right table ?
            if 'japan' in str(row[y]).lower().strip():
                t = True
                # Is this the right row ?
            if 'total' in str(row[y]).lower() or 'confirmed' in str(row[y]).lower():
                r = True
            if r == True & t == True:
                if str(row[y]).split('.')[0].replace(',', '').isdigit():
                    return row['Date'].date(), int(str(row[y]).split('.')[0].replace(',', '')), row['Filename']

def createDataframe(pages):
    dates, confirmedCases, file=[],[],[]
    for page in pages:
        if len(page)>0:
            for i, df in enumerate(page):
                try:
                    dt, number, filename = findNumber(df)
                    dates.append(dt)
                    confirmedCases.append(number)
                    file.append(filename)
                    ##print(dt,number, filename)
                    #if number==4593:
                    #    print(str(i)+':'+filename)
                    if filename=='20200128-sitrep-8-ncov-cleared.pdf':
                        print(df)
                    break
                except Exception as e:
                    pass
    dataTable=pd.DataFrame({'Date':dates, 'confirmedcases':confirmedCases, 'File':file})
    dataTable=dataTable.sort_values('Date')
    dataTable['C'] = np.arange(len(dataTable))+1
    dataTable=dataTable.sort_values('C')

    dataTable=dataTable.drop_duplicates(subset=['Date','File','confirmedcases','C'])
    print("Writing csv-file")
    dataTable.to_csv('../data/dataTable.csv')


if __name__=='__main__':
    delete()
    download()
    print("Extracting data from pdfs")
    pages=[]
    for filename in os.listdir('../data/'):
        if filename.endswith('.pdf'):
            print('   Ectracting from '+filename)
            dt=(filename[:8])
            dflist = tabula.read_pdf('../data/'+filename, pages='all', silent=True)
            for df in dflist:
                df['Date']=pd.Series([pd.to_datetime(dt) for i in range(0, len(df))])
                df['Filename']=pd.Series([filename for i in range(0, len(df))])
        pages.append(dflist)
    #print(pages)
    createDataframe(pages)
    print("Done, all is well")
# Out:
# Writing 20200202-sitrep-13-ncov-v3.pdf
# Writing 20200201-sitrep-12-ncov.pdf
# Writing 20200131-sitrep-11-ncov.pdf
# Writing 20200130-sitrep-10-ncov.pdf
# Writing 20200129-sitrep-9-ncov-v2.pdf
# Writing 20200128-sitrep-8-ncov-cleared.pdf
